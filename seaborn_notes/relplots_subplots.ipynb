# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("E:\VSCode\PythonNotes\seaborn_notes\student-alcohol-consumption.csv")
sns.relplot(x = "absences", y="G3", 
            data=df,
            kind="scatter", 
            col="study_time")

# %% [markdown]
# plotting with two extra parameters famsup (family support ) and schoolsup(school support)

# %%
df = pd.read_csv("E:\VSCode\PythonNotes\seaborn_notes\student-alcohol-consumption.csv")
sns.relplot(x="G1", y="G3", 
            data=df,
            kind="scatter", 
            col="schoolsup",
            row='famsup',
            row_order=["yes","no"],
            col_order=["yes", "no"])

# %% [markdown]
# #### POINT SIZE, COLORS, STYLE...

# %%
mpg = pd.read_csv("E:\VSCode\PythonNotes\seaborn_notes\mileage_per_gallon.csv")
sns.relplot(x="horsepower", y="mpg", 
            data=mpg, kind="scatter", 
            size="cylinders", hue = "cylinders", alpha = 0.7)

# %%
mpg = pd.read_csv("E:\VSCode\PythonNotes\seaborn_notes\mileage_per_gallon.csv")
sns.relplot(x="acceleration", y="mpg", data=mpg, style="origin", hue="origin", alpha=0.6, size = "horsepower")
